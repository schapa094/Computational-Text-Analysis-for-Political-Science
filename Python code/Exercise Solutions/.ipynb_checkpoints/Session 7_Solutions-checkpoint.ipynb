# %% [markdown]
# # Lemmatization and Stemming

# %%
import numpy as np
from numpy import *
from numpy import random # random data
import csv
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from itertools import chain
import nltk
nltk.download('punkt')
import codecs
import string
from nltk.corpus import stopwords
import re
import pprint
import random
from urllib import request
from nltk import word_tokenize
from nltk.corpus import brown
from nltk.corpus import wordnet as wn

from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer("english")
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /Users/Ashrakat/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Lets take a look at what we have learned until now.

# %%
dataset = codecs.open("/Users/Ashrakat/Desktop/rt_dataset.tsv", "r", "utf-8").read().strip().split("\n")

# %%
# take a single article
article = dataset[50].split("\t")[3]


# split into sentences
sentences = nltk.sent_tokenize(article) 

# take one single sentence (I'm adding a number at the end - just for testing that stripping numbers work fine)
sentence = sentences[4] + " 5"
print(" ")

print (sentence)

# word tokenizer
sentence = nltk.word_tokenize(sentence)
print(" ")

print ("Tokenizer:\n",sentence)


# lowering words
sentence = [word.lower() for word in sentence]
print(" ")

print ("lower-cased:\n",sentence)


# defining stop-words (it's a list)
stop_word_list = stopwords.words('english')


# removing stopwords
sentence = [word for word in sentence if word not in stop_word_list]
print(" ")

print ("without stopwords:\n",sentence)


# defining punctuation to be removed
exclude = set(string.punctuation)

#
sentence = [token for token in sentence if token not in exclude]
print(" ")

print ("without punctuation:\n",sentence)


#remove punctuations and numbers
sentence = [word for word in sentence if word.isalpha()]
print(" ")
print("without punctuation and numbers:\n",sentence)
# Out:
#
# DAMN Fans took to Twitter in their droves to commend the team and their supporters for their classy performance that many credited as the highlight of Euro-2016 so far. 5
#
# Tokenizer:
#  ['DAMN', 'Fans', 'took', 'to', 'Twitter', 'in', 'their', 'droves', 'to', 'commend', 'the', 'team', 'and', 'their', 'supporters', 'for', 'their', 'classy', 'performance', 'that', 'many', 'credited', 'as', 'the', 'highlight', 'of', 'Euro-2016', 'so', 'far', '.', '5']
#
# lower-cased:
#  ['damn', 'fans', 'took', 'to', 'twitter', 'in', 'their', 'droves', 'to', 'commend', 'the', 'team', 'and', 'their', 'supporters', 'for', 'their', 'classy', 'performance', 'that', 'many', 'credited', 'as', 'the', 'highlight', 'of', 'euro-2016', 'so', 'far', '.', '5']
#
# without stopwords:
#  ['damn', 'fans', 'took', 'twitter', 'droves', 'commend', 'team', 'supporters', 'classy', 'performance', 'many', 'credited', 'highlight', 'euro-2016', 'far', '.', '5']
#
# without punctuation:
#  ['damn', 'fans', 'took', 'twitter', 'droves', 'commend', 'team', 'supporters', 'classy', 'performance', 'many', 'credited', 'highlight', 'euro-2016', 'far', '5']
#
# without punctuation and numbers:
#  ['damn', 'fans', 'took', 'twitter', 'droves', 'commend', 'team', 'supporters', 'classy', 'performance', 'many', 'credited', 'highlight', 'far']

# %% [markdown]
# # Stemming
#
# ## We reduce the word to its stem basically, we reduce words to their core root
#
# - Put in simple terms: several conditions that the stemmer evaluates
# - Mapping a group of words to the same stem
# - May result in non-words, rather stems of the actual words
# - chopping off the last part of the word

# %% [markdown]
# ## When can it be helpful
#
# - Information retrieval setting and you want to boost your algorithm’s recall. (Recall is defined as the number of relevant documents retrieved by a search divided by the total number of existing relevant documents)
# - Query Expansion: Search Environments which refers to that when a user inputs a query. It is used to expand or enhance the query to match additional documents
# - World usaga analysis in a corpus, we wish to condense words to reduce variabilitu.
# - Sentiment Analysis
# - Classification tasks
#
# ## Take care of overstemming and understemming

# %%
list1=["university", "universal", "universities", "universe"]
stem_list1 = [snowball_stemmer.stem(word) for word in list1]
stem_list1
# Out:
# ['univers', 'univers', 'univers', 'univers']

# %%
list2=[ "data" , "datum","date"]
stem_list2 = [snowball_stemmer.stem(word) for word in list2]
stem_list2
# Out:
# ['data', 'datum', 'date']

# %% [markdown]
# Difference between the porter and lancaster stemming algorithms:
# - Three main stemming mechanisms iare **Porter, Snowball(Porter2), Lancaster**
# - Lancaster is more aggressive that porter
# - Snowball stemmer has applications in different European languages
# - Russian is surprisingly easy to process

# %%
# import the library
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer("english")

print ("tokenized:\n",sentence)

stem_sentence = [snowball_stemmer.stem(word) for word in sentence]

print ("stemmed:\n",stem_sentence)
# Out:
# tokenized ['damn', 'fans', 'took', 'twitter', 'droves', 'commend', 'team', 'supporters', 'classy', 'performance', 'many', 'credited', 'highlight', 'far']
# stemmed ['damn', 'fan', 'took', 'twitter', 'drove', 'commend', 'team', 'support', 'classi', 'perform', 'mani', 'credit', 'highlight', 'far']

# %%
import nltk
import re
import pprint
import random
from urllib import request
from nltk import word_tokenize
from nltk.corpus import brown
from nltk.corpus import wordnet as wn

article = """Donald John Trump (born June 14, 1946) is the 45th and current president of the United States. Before entering politics, he was a businessman and television personality.
Trump was born and raised in Queens, a borough of New York City, and received a bachelor's degree in economics from the Wharton School. He took charge of his family's real-estate business in 1971, renamed it The Trump Organization, and expanded its operations from Queens and Brooklyn into Manhattan. The company built or renovated skyscrapers, hotels, casinos, and golf courses. Trump later started various side ventures, mostly by licensing his name. He produced and hosted The Apprentice, a reality television series, from 2003 to 2015. As of 2020, Forbes estimated his net worth to be $2.1 billion.[a]
Trump entered the 2016 presidential race as a Republican and defeated 16 other candidates in the primaries. His political positions have been described as populist, protectionist, and nationalist. Despite not being favored in most forecasts, he was elected over Democratic nominee Hillary Clinton, although he lost the popular vote. """
# from Wikipedia https://en.wikipedia.org/wiki/Donald_Trump

tokens = word_tokenize(article)

snowball = SnowballStemmer("english")
porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()

snowball_output = [snowball_stemmer.stem(t) for t in tokens]             
porter_output = [porter.stem(t) for t in tokens]             
lancaster_output = [lancaster.stem(t) for t in tokens]

# %%
print(porter_output)
# Out:
# ['donald', 'john', 'trump', '(', 'born', 'june', '14', ',', '1946', ')', 'is', 'the', '45th', 'and', 'current', 'presid', 'of', 'the', 'unit', 'state', '.', 'befor', 'enter', 'polit', ',', 'he', 'wa', 'a', 'businessman', 'and', 'televis', 'person', '.', 'trump', 'wa', 'born', 'and', 'rais', 'in', 'queen', ',', 'a', 'borough', 'of', 'new', 'york', '
# %%
print(lancaster_output)
# Out:
# ['donald', 'john', 'trump', '(', 'born', 'jun', '14', ',', '1946', ')', 'is', 'the', '45th', 'and', 'cur', 'presid', 'of', 'the', 'unit', 'stat', '.', 'bef', 'ent', 'polit', ',', 'he', 'was', 'a', 'businessm', 'and', 'televid', 'person', '.', 'trump', 'was', 'born', 'and', 'rais', 'in', 'queen', ',', 'a', 'borough', 'of', 'new', 'york', 'city', ',', 'and', 'receiv', 'a', 'bachel', "'s", 'degr', 'in', 'econom', 'from', 'the', 'wharton', 'school', '.', 'he', 'took', 'charg', 'of', 'his', 'famy', "'s", 'real-estate', 'busy', 'in', '1971', ',', 'renam', 'it', 'the', 'trump', 'org', ',', 'and', 'expand', 'it', 'op', 'from', 'queen', 'and', 'brooklyn', 'into', 'manhat', '.', 'the', 'company', 'built', 'or', 'renov', 'skyscrap', ',', 'hotel', ',', 'casino', ',', 'and', 'golf', 'cours', '.', 'trump', 'lat', 'start', 'vary', 'sid', 'vent', ',', 'most', 'by', 'licens', 'his', 'nam', '.', 'he', 'produc', 'and', 'host', 'the', 'appr', ',', 'a', 'real', 'televid', 'sery', ',', 'from', '2003', 'to', '2015', '.', 'as', 'of', '2020', ',', 'forb', 'estim', 'his', 'net', 'wor', 'to', 'be', '$', '2.1', 'bil', '.', '[', 'a', ']', 'trump', 'ent', 'the', '2016', 'presid', 'rac', 'as', 'a', 'republ', 'and', 'def', '16', 'oth', 'candid', 'in', 'the', 'prim', '.', 'his', 'polit', 'posit', 'hav', 'been', 'describ', 'as', 'pop', ',', 'protect', ',', 'and', 'nat', '.', 'despit', 'not', 'being', 'fav', 'in', 'most', 'forecast', ',', 'he', 'was', 'elect', 'ov', 'democr', 'nomin', 'hil', 'clinton', ',', 'although', 'he', 'lost', 'the', 'popul', 'vot', '.']

# %%
#A list of words to be stemmed
word_list = ["friend", "friendship", "friends", "friendships","stabil","destabilize","misunderstanding","railroad","moonlight","football"]
print("{0:20}{1:20}{2:20}".format("Word","Snowball Stemmer","lancaster Stemmer"))
for word in word_list:
    print("{0:20}{1:20}{2:20}".format(word,snowball_stemmer.stem(word),lancaster.stem(word)))
    
#https://www.datacamp.com/community/tutorials/stemming-lemmatization-python
# Out:
# Word                Snowball Stemmer    lancaster Stemmer
# friend              friend              friend
# friendship          friendship          friend
# friends             friend              friend
# friendships         friendship          friend
# stabil              stabil              stabl
# destabilize         destabil            dest
# misunderstanding    misunderstand       misunderstand
# railroad            railroad            railroad
# moonlight           moonlight           moonlight
# football            footbal             footbal

# %% [markdown]
# # Lemmatization
# ## Setting words to their dictionary form
# The process of grouping together the inflected forms of a word as a single
# item.
#
#
# ## Employing Wordnet - large lexical database of English
#
# read more about wordnet here: https://wordnet.princeton.edu/

# %% [markdown]
# ## When is it benefitial to lemmatize?
#
# - Topic modeling: relies on the distribution of words, the identification of which is dependent on a string match between words, which is achieved by lemmatizing their forms so that all variants are consistent across documents
# - Sentiment Analysis
# - Classification tasks
#
# - The general rule: if it does not help your performance, do not lemmatize.
#
# - Some sentiment analysis methods can have different performance according to lemmitazation

# %%
from nltk.stem.wordnet import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()

# %%
list3=["fishes", "fishing", "fish"]
lemma_list3 = [wordnet_lemmatizer.lemmatize(word) for word in list3]
lemma_list3

stem_list3 = [snowball_stemmer.stem(word) for word in list3]
stem_list3 # here we map a group of words to the same stem

print("lemmatization:", lemma_list3)
print("stemming:", stem_list3)# here we map a group of words to the same stem
# Out:
# lemmatization: ['fish', 'fishing', 'fish']
# stemming: ['fish', 'fish', 'fish']

# %%
party=["party", "partying","parties"]
lemma_party = [wordnet_lemmatizer.lemmatize(word) for word in party]
stem_party = [snowball_stemmer.stem(word) for word in party]
# Out:
# lemmatization: ['party', 'partying', 'party']
# stemming: ['parti', 'parti', 'parti']

# %%
# see the difference it doesnt treat verbs for example similarly

# %%
list4=["connections","connecting","connect","connected","connection"]
lemma_list4 = [wordnet_lemmatizer.lemmatize(word) for word in list4]
stem_list4 = [snowball_stemmer.stem(word) for word in list4]
print("lemmatization:", lemma_list4)
print("stemming:", stem_list4)
# Out:
# lemmatization: ['connection', 'connecting', 'connect', 'connected', 'connection']
# stemming: ['connect', 'connect', 'connect', 'connect', 'connect']

# %%
lemma_sent = [wordnet_lemmatizer.lemmatize(word) for word in sentence]
stem_sentence = [snowball_stemmer.stem(word) for word in sentence]

print ("stemmed:\n", stem_sentence)
print(" ")
print ("lemmatized:\n",lemma_sent)
# Out:
# stemmed:
#  ['damn', 'fan', 'took', 'twitter', 'drove', 'commend', 'team', 'support', 'classi', 'perform', 'mani', 'credit', 'highlight', 'far']
#
# lemmatized:
#  ['damn', 'fan', 'took', 'twitter', 'drove', 'commend', 'team', 'supporter', 'classy', 'performance', 'many', 'credited', 'highlight', 'far']

# %%
#A list of words to be stemmed and lemmatized
word_list = ["friend", "friendship", "friends", "friendships","stabil","destabilize",\
             "misunderstanding","railroad","moonlight","football","party","extreme",\
             "muslim","islam","political","politics","perfect"]
print("{0:20}{1:20}{2:20}".format("Word","Snowball Stemmer","Lemmatizing"))
for word in word_list:
    print("{0:20}{1:20}{2:20}".format(word,snowball_stemmer.stem(word),wordnet_lemmatizer.lemmatize(word)))
# Out:
# Word                Snowball Stemmer    Lemmatizing
# friend              friend              friend
# friendship          friendship          friendship
# friends             friend              friend
# friendships         friendship          friendship
# stabil              stabil              stabil
# destabilize         destabil            destabilize
# misunderstanding    misunderstand       misunderstanding
# railroad            railroad            railroad
# moonlight           moonlight           moonlight
# football            footbal             football
# party               parti               party
# extreme             extrem              extreme
# muslim              muslim              muslim
# islam               islam               islam
# political           polit               political
# politics            polit               politics
# perfect             perfect             perfect

# %%
# Out:
# ['damn', 'fan', 'took', 'twitter', 'drove', 'commend', 'team', 'supporter', 'classy', 'performance', 'many', 'credited', 'highlight', 'far']

# %%
print('Original Article: %s' % (article))
print()

for token in tokens:
    lemmatized_token = wordnet_lemmatizer.lemmatize(token)
    
    if token != lemmatized_token:
        print('Original : %s, New: %s' % (token, lemmatized_token))
        
#inspired by edward ma
# Out:
# Original Article: Donald John Trump (born June 14, 1946) is the 45th and current president of the United States. Before entering politics, he was a businessman and television personality.
# Trump was born and raised in Queens, a borough of New York City, and received a bachelor's degree in economics from the Wharton School. He took charge of his family's real-estate business in 1971, renamed it The Trump Organization, and expanded its operations from Queens and Brooklyn into Manhattan. The company built or renovated skyscrapers, hotels, casinos, and golf courses. Trump later started various side ventures, mostly by licensing his name. He produced and hosted The Apprentice, a reality television series, from 2003 to 2015. As of 2020, Forbes estimated his net worth to be $2.1 billion.[a]
# Trump entered the 2016 presidential race as a Republican and defeated 16 other candidates in the primaries. His political positions have been described as populist, protectionist, and nationalist. Despite not being favored in most forecasts, he was elected over Democratic nominee Hillary Clinton, although he lost the popular vote.
#
# Original : was, New: wa
# Original : was, New: wa
# Original : its, New: it
# Original : operations, New: operation
# Original : skyscrapers, New: skyscraper
# Original : hotels, New: hotel
# Original : casinos, New: casino
# Original : courses, New: course
# Original : ventures, New: venture
# Original : as, New: a
# Original : candidates, New: candidate
# Original : primaries, New: primary
# Original : positions, New: position
# Original : as, New: a
# Original : forecasts, New: forecast
# Original : was, New: wa

# %% [markdown]
# # - Always check if employing those methods will improve your performance!
#
# *Stemming can sometimes combine together words with substantively different meanings:<br\>
# (“college students partying”, and “political parties”), which might be misleading in practice (Denny and Spirling 2018)

# %% [markdown]
# # - Think about the order in your NLP Pipeline

# %% [markdown]
# # Excercises

# %% [markdown]
# **Excercise 1**
#
# Load the sascat_excerpt.tsv data.
#
#
# a) drop all columns but the id and the content
#
# b) Use pandas to create a column for each of the following:
#
# 1. content - only lowercased
# 2. content - lowercased, removed punctuation, removed numbers
# 3. using the whole naive pipleline
# 4. using a pipeline (usual text processing steps) with tokenizer
# 5. using a pipeline (usual text processing steps) using tokenizer and stemmer (snowball)
# 6. using a pipeline (usual text processing steps) using tokenizer and lemmetizer
#
#
# d) please write a paragraph using the Markdown function of what you think are the main differences between the 4 columns with text
#
# (it can be useful to write out this file to your harddrive to take a closer look)
#
# e) what are the most frequent 5 words using the last pipeline
#
# c) plot word frequency of these topics in a matplot
#
# e) write out this output as a comma seperated file for furture use.

# %%
sascat = pd.read_csv('/Users/Ashrakat/Desktop/sascat_excerpt.tsv',delimiter="\t")

sascat.head()
# Out:
#      id-snippet  n-sentences  n-words  n-nouns  n-adj  n-verbs  n-entities  \
# 0  hr5114-101.1           20      839      441     83       87          76
# 1  hr5114-101.2            5      159       77     21       21           9
# 2  hr5114-101.3            1       56       29      4        5           3
# 3  hr5114-101.4            1      110       49     14       12          11
# 4  hr5114-101.5            1       27       13      1        6           2
#
#    n-vague  n-concrete  n-conditionals  \
# 0        3           4               5
# 1        2           1               1
# 2        2           1               1
# 3        1           0               2
# 4        1           0               0
#
#                                          Unnamed: 10
# 0  Provides for the enforcement of all provisions...
# 1  Requires the delivery of excess defense articl...
# 2  Prohibits making available any ESF or foreign ...
# 3  Prohibits the obligation of funds for the Euro...
# 4  Prohibits assistance to countries which fail t...

# %%
sascat.rename(columns={'id-snippet':'id'}, 
                 inplace=True)
sascat.rename(columns={'Unnamed: 10':'content'}, 
                 inplace=True)
sascat = sascat[['content','id']]

sascat.head()
# Out:
#                                              content            id
# 0  Provides for the enforcement of all provisions...  hr5114-101.1
# 1  Requires the delivery of excess defense articl...  hr5114-101.2
# 2  Prohibits making available any ESF or foreign ...  hr5114-101.3
# 3  Prohibits the obligation of funds for the Euro...  hr5114-101.4
# 4  Prohibits assistance to countries which fail t...  hr5114-101.5

# %%
#create a column for each of the following
#1. lower cased
sascat["lower"]=sascat['content'].str.lower()

# %%
sascat.head()
# Out:
#                                              content            id  \
# 0  Provides for the enforcement of all provisions...  hr5114-101.1
# 1  Requires the delivery of excess defense articl...  hr5114-101.2
# 2  Prohibits making available any ESF or foreign ...  hr5114-101.3
# 3  Prohibits the obligation of funds for the Euro...  hr5114-101.4
# 4  Prohibits assistance to countries which fail t...  hr5114-101.5
#
#                                                lower
# 0  provides for the enforcement of all provisions...
# 1  requires the delivery of excess defense articl...
# 2  prohibits making available any esf or foreign ...
# 3  prohibits the obligation of funds for the euro...
# 4  prohibits assistance to countries which fail t...

# %%
#2. content - lowercased, removed punctuation, removed numbers


exclude = set(string.punctuation)
def nlp1(text): 
    try:
        text = ''.join(ch for ch in text if ch not in exclude) #remove punctuation
        text=re.sub('[0-9]+', '', text) # remove numbers
        text=text.lower()# lower text
        return text
    except:
        return None

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

sascat['clean2'] = sascat['content'].astype(str)
sascat['clean2'] = sascat['content'].apply(nlp1)

# %%
sascat
# Out:
#                                               content             id  \
# 0   Provides for the enforcement of all provisions...   hr5114-101.1
# 1   Requires the delivery of excess defense articl...   hr5114-101.2
# 2   Prohibits making available any ESF or foreign ...   hr5114-101.3
# 3   Prohibits the obligation of funds for the Euro...   hr5114-101.4
# 4   Prohibits assistance to countries which fail t...   hr5114-101.5
# ..                                                ...            ...
# 95  Earmarks ESF and development assistance availa...  hr5368-102.16
# 96  Expresses the sense of the Congress that the r...  hr5368-102.17
# 97                 Prohibits ESF assistance to Zaire.  hr5368-102.18
# 98  Limits the amount of ESF assistance for tied a...  hr5368-102.19
# 99  Withholds a specified amount of funds allocate...  hr5368-102.20
#
#                                                 lower  \
# 0   provides for the enforcement of all provisions...
# 1   requires the delivery of excess defense articl...
# 2   prohibits making available any esf or foreign ...
# 3   prohibits the obligation of funds for the euro...
# 4   prohibits assistance to countries which fail t...
# ..                                                ...
# 95  earmarks esf and development assistance availa...
# 96  expresses the sense of the congress that the r...
# 97                 prohibits esf assistance to zaire.
# 98  limits the amount of esf assistance for tied a...
# 99  withholds a specified amount of funds allocate...
#
#                                                clean2
# 0   provides for the enforcement of all provisions...
# 1   requires the delivery of excess defense articl...
# 2   prohibits making available any esf or foreign ...
# 3   prohibits the obligation of funds for the euro...
# 4   prohibits assistance to countries which fail t...
# ..                                                ...
# 95  earmarks esf and development assistance availa...
# 96  expresses the sense of the congress that the r...
# 97                  prohibits esf assistance to zaire
# 98  limits the amount of esf assistance for tied a...
# 99  withholds a specified amount of funds allocate...
#
# [100 rows x 4 columns]

# %%
#3. using the whole naive pipleline 

def clean3(x):
        x=x.lower()# lower text
        x = ''.join(ch for ch in x if ch not in exclude) #remove punctuation
        x=re.sub('[0-9]+', '', x) # remove numbers
        x=x.split() #split words 
        x=[word for word in x if word not in stopwords.words('english')]#remove stopwords
        #x=" ".join(str(x) for x in x) # you can do this if you want to remove list structure
        return x

# %%
sascat['clean3'] = sascat['content'].apply(clean3)

# %%
sascat.head()
# Out:
#                                              content            id  \
# 0  Provides for the enforcement of all provisions...  hr5114-101.1
# 1  Requires the delivery of excess defense articl...  hr5114-101.2
# 2  Prohibits making available any ESF or foreign ...  hr5114-101.3
# 3  Prohibits the obligation of funds for the Euro...  hr5114-101.4
# 4  Prohibits assistance to countries which fail t...  hr5114-101.5
#
#                                                lower  \
# 0  provides for the enforcement of all provisions...
# 1  requires the delivery of excess defense articl...
# 2  prohibits making available any esf or foreign ...
# 3  prohibits the obligation of funds for the euro...
# 4  prohibits assistance to countries which fail t...
#
#                                               clean2  \
# 0  provides for the enforcement of all provisions...
# 1  requires the delivery of excess defense articl...
# 2  prohibits making available any esf or foreign ...
# 3  prohibits the obligation of funds for the euro...
# 4  prohibits assistance to countries which fail t...
#
#                                               clean3
# 0  [provides, enforcement, provisions, law, impos...
# 1  [requires, delivery, excess, defense, articles...
# 2  [prohibits, making, available, esf, foreign, m...
# 3  [prohibits, obligation, funds, european, bank,...
# 4  [prohibits, assistance, countries, fail, take,...

# %%
#4. using a pipeline (usual text processing steps) with tokenizer

def nlp_pipeline(text):
    
    text=text.lower()

    #tokenize words for each sentence
    text = nltk.word_tokenize(text)
    
    # remove punctuation and numbers
    text = [token for token in text if token.isalpha()]#The isalpha() keeps here caracters in the string are alphabets
    
    # remove stopwords - be careful with this step    
    text = [token for token in text if token not in stop_words]

    return text

sascat['clean4'] = sascat['content'].apply(nlp_pipeline)

# %%
sascat.head()
# Out:
#                                              content            id  \
# 0  Provides for the enforcement of all provisions...  hr5114-101.1
# 1  Requires the delivery of excess defense articl...  hr5114-101.2
# 2  Prohibits making available any ESF or foreign ...  hr5114-101.3
# 3  Prohibits the obligation of funds for the Euro...  hr5114-101.4
# 4  Prohibits assistance to countries which fail t...  hr5114-101.5
#
#                                                lower  \
# 0  provides for the enforcement of all provisions...
# 1  requires the delivery of excess defense articl...
# 2  prohibits making available any esf or foreign ...
# 3  prohibits the obligation of funds for the euro...
# 4  prohibits assistance to countries which fail t...
#
#                                               clean2  \
# 0  provides for the enforcement of all provisions...
# 1  requires the delivery of excess defense articl...
# 2  prohibits making available any esf or foreign ...
# 3  prohibits the obligation of funds for the euro...
# 4  prohibits assistance to countries which fail t...
#
#                                               clean3  \
# 0  [provides, enforcement, provisions, law, impos...
# 1  [requires, delivery, excess, defense, articles...
# 2  [prohibits, making, available, esf, foreign, m...
# 3  [prohibits, obligation, funds, european, bank,...
# 4  [prohibits, assistance, countries, fail, take,...
#
#                                               clean4
# 0  [provides, enforcement, provisions, law, impos...
# 1  [requires, delivery, excess, defense, articles...
# 2  [prohibits, making, available, esf, foreign, m...
# 3  [prohibits, obligation, funds, european, bank,...
# 4  [prohibits, assistance, countries, fail, take,...

# %%
#5. using a pipeline (usual text processing steps) using tokenizer and stemmer
def nlp_pipeline2(text):
    
    text=text.lower()

    #tokenize words for each sentence
    text = nltk.word_tokenize(text)
    
    # remove punctuation and numbers
    text = [token for token in text if token.isalpha()]#The isalpha() keeps here caracters in the string are alphabets
    
    # remove stopwords - be careful with this step    
    text = [token for token in text if token not in stop_words]
    
    text = [snowball_stemmer.stem(token) for token in text]


    return text

sascat['clean5'] = sascat['content'].apply(nlp_pipeline2)
sascat
# Out:
#                                               content             id  \
# 0   Provides for the enforcement of all provisions...   hr5114-101.1
# 1   Requires the delivery of excess defense articl...   hr5114-101.2
# 2   Prohibits making available any ESF or foreign ...   hr5114-101.3
# 3   Prohibits the obligation of funds for the Euro...   hr5114-101.4
# 4   Prohibits assistance to countries which fail t...   hr5114-101.5
# ..                                                ...            ...
# 95  Earmarks ESF and development assistance availa...  hr5368-102.16
# 96  Expresses the sense of the Congress that the r...  hr5368-102.17
# 97                 Prohibits ESF assistance to Zaire.  hr5368-102.18
# 98  Limits the amount of ESF assistance for tied a...  hr5368-102.19
# 99  Withholds a specified amount of funds allocate...  hr5368-102.20
#
#                                                 lower  \
# 0   provides for the enforcement of all provisions...
# 1   requires the delivery of excess defense articl...
# 2   prohibits making available any esf or foreign ...
# 3   prohibits the obligation of funds for the euro...
# 4   prohibits assistance to countries which fail t...
# ..                                                ...
# 95  earmarks esf and development assistance availa...
# 96  expresses the sense of the congress that the r...
# 97                 prohibits esf assistance to zaire.
# 98  limits the amount of esf assistance for tied a...
# 99  withholds a specified amount of funds allocate...
#
#                                                clean2  \
# 0   provides for the enforcement of all provisions...
# 1   requires the delivery of excess defense articl...
# 2   prohibits making available any esf or foreign ...
# 3   prohibits the obligation of funds for the euro...
# 4   prohibits assistance to countries which fail t...
# ..                                                ...
# 95  earmarks esf and development assistance availa...
# 96  expresses the sense of the congress that the r...
# 97                  prohibits esf assistance to zaire
# 98  limits the amount of esf assistance for tied a...
# 99  withholds a specified amount of funds allocate...
#
#                                                clean3  \
# 0   [provides, enforcement, provisions, law, impos...
# 1   [requires, delivery, excess, defense, articles...
# 2   [prohibits, making, available, esf, foreign, m...
# 3   [prohibits, obligation, funds, european, bank,...
# 4   [prohibits, assistance, countries, fail, take,...
# ..                                                ...
# 95  [earmarks, esf, development, assistance, avail...
# 96  [expresses, sense, congress, recommended, leve...
# 97                [prohibits, esf, assistance, zaire]
# 98  [limits, amount, esf, assistance, tied, aid, c...
# 99  [withholds, specified, amount, funds, allocate...
#
#                                                clean4  \
# 0   [provides, enforcement, provisions, law, impos...
# 1   [requires, delivery, excess, defense, articles...
# 2   [prohibits, making, available, esf, foreign, m...
# 3   [prohibits, obligation, funds, european, bank,...
# 4   [prohibits, assistance, countries, fail, take,...
# ..                                                ...
# 95  [earmarks, esf, development, assistance, avail...
# 96  [expresses, sense, congress, recommended, leve...
# 97                [prohibits, esf, assistance, zaire]
# 98  [limits, amount, esf, assistance, tied, aid, c...
# 99  [withholds, specified, amount, funds, allocate...
#
#                                                clean5
# 0   [provid, enforc, provis, law, impos, sanction,...
# 1   [requir, deliveri, excess, defens, articl, nat...
# 2   [prohibit, make, avail, esf, foreign, militari...
# 3   [prohibit, oblig, fund, european, bank, recons...
# 4   [prohibit, assist, countri, fail, take, step, ...
# ..                                                ...
# 95  [earmark, esf, develop, assist, avail, humanit...
# 96  [express, sens, congress, recommend, level, es...
# 97                      [prohibit, esf, assist, zair]
# 98  [limit, amount, esf, assist, tie, aid, credit,...
# 99  [withhold, specifi, amount, fund, alloc, domin...
#
# [100 rows x 7 columns]

# %%
#6. using a pipeline (usual text processing steps) using tokenizer and lemmetizer
def nlp_pipeline3(text):
    
    text=text.lower()

    #tokenize words for each sentence
    text = nltk.word_tokenize(text)
    
    # remove punctuation and numbers
    text = [token for token in text if token.isalpha()]#The isalpha() keeps here caracters in the string are alphabets
    
    # remove stopwords - be careful with this step    
    text = [token for token in text if token not in stop_words]
    
    text = [wordnet_lemmatizer.lemmatize(token) for token in text]


    return text

sascat['clean6'] = sascat['content'].apply(nlp_pipeline3)
sascat
# Out:
#                                               content             id  \
# 0   Provides for the enforcement of all provisions...   hr5114-101.1
# 1   Requires the delivery of excess defense articl...   hr5114-101.2
# 2   Prohibits making available any ESF or foreign ...   hr5114-101.3
# 3   Prohibits the obligation of funds for the Euro...   hr5114-101.4
# 4   Prohibits assistance to countries which fail t...   hr5114-101.5
# ..                                                ...            ...
# 95  Earmarks ESF and development assistance availa...  hr5368-102.16
# 96  Expresses the sense of the Congress that the r...  hr5368-102.17
# 97                 Prohibits ESF assistance to Zaire.  hr5368-102.18
# 98  Limits the amount of ESF assistance for tied a...  hr5368-102.19
# 99  Withholds a specified amount of funds allocate...  hr5368-102.20
#
#                                                 lower  \
# 0   provides for the enforcement of all provisions...
# 1   requires the delivery of excess defense articl...
# 2   prohibits making available any esf or foreign ...
# 3   prohibits the obligation of funds for the euro...
# 4   prohibits assistance to countries which fail t...
# ..                                                ...
# 95  earmarks esf and development assistance availa...
# 96  expresses the sense of the congress that the r...
# 97                 prohibits esf assistance to zaire.
# 98  limits the amount of esf assistance for tied a...
# 99  withholds a specified amount of funds allocate...
#
#                                                clean2  \
# 0   provides for the enforcement of all provisions...
# 1   requires the delivery of excess defense articl...
# 2   prohibits making available any esf or foreign ...
# 3   prohibits the obligation of funds for the euro...
# 4   prohibits assistance to countries which fail t...
# ..                                                ...
# 95  earmarks esf and development assistance availa...
# 96  expresses the sense of the congress that the r...
# 97                  prohibits esf assistance to zaire
# 98  limits the amount of esf assistance for tied a...
# 99  withholds a specified amount of funds allocate...
#
#                                                clean3  \
# 0   [provides, enforcement, provisions, law, impos...
# 1   [requires, delivery, excess, defense, articles...
# 2   [prohibits, making, available, esf, foreign, m...
# 3   [prohibits, obligation, funds, european, bank,...
# 4   [prohibits, assistance, countries, fail, take,...
# ..                                                ...
# 95  [earmarks, esf, development, assistance, avail...
# 96  [expresses, sense, congress, recommended, leve...
# 97                [prohibits, esf, assistance, zaire]
# 98  [limits, amount, esf, assistance, tied, aid, c...
# 99  [withholds, specified, amount, funds, allocate...
#
#                                                clean4  \
# 0   [provides, enforcement, provisions, law, impos...
# 1   [requires, delivery, excess, defense, articles...
# 2   [prohibits, making, available, esf, foreign, m...
# 3   [prohibits, obligation, funds, european, bank,...
# 4   [prohibits, assistance, countries, fail, take,...
# ..                                                ...
# 95  [earmarks, esf, development, assistance, avail...
# 96  [expresses, sense, congress, recommended, leve...
# 97                [prohibits, esf, assistance, zaire]
# 98  [limits, amount, esf, assistance, tied, aid, c...
# 99  [withholds, specified, amount, funds, allocate...
#
#                                                clean5  \
# 0   [provid, enforc, provis, law, impos, sanction,...
# 1   [requir, deliveri, excess, defens, articl, nat...
# 2   [prohibit, make, avail, esf, foreign, militari...
# 3   [prohibit, oblig, fund, european, bank, recons...
# 4   [prohibit, assist, countri, fail, take, step, ...
# ..                                                ...
# 95  [earmark, esf, develop, assist, avail, humanit...
# 96  [express, sens, congress, recommend, level, es...
# 97                      [prohibit, esf, assist, zair]
# 98  [limit, amount, esf, assist, tie, aid, credit,...
# 99  [withhold, specifi, amount, fund, alloc, domin...
#
#                                                clean6
# 0   [provides, enforcement, provision, law, impose...
# 1   [requires, delivery, excess, defense, article,...
# 2   [prohibits, making, available, esf, foreign, m...
# 3   [prohibits, obligation, fund, european, bank, ...
# 4   [prohibits, assistance, country, fail, take, s...
# ..                                                ...
# 95  [earmark, esf, development, assistance, availa...
# 96  [express, sense, congress, recommended, level,...
# 97                [prohibits, esf, assistance, zaire]
# 98  [limit, amount, esf, assistance, tied, aid, cr...
# 99  [withholds, specified, amount, fund, allocated...
#
# [100 rows x 8 columns]

# %%
#a) most frequent topics
sascat['clean6'] = [' '.join(map(str, l)) for l in sascat['clean6']]

# %%
sascat
# Out:
#                                               content             id  \
# 0   Provides for the enforcement of all provisions...   hr5114-101.1
# 1   Requires the delivery of excess defense articl...   hr5114-101.2
# 2   Prohibits making available any ESF or foreign ...   hr5114-101.3
# 3   Prohibits the obligation of funds for the Euro...   hr5114-101.4
# 4   Prohibits assistance to countries which fail t...   hr5114-101.5
# ..                                                ...            ...
# 95  Earmarks ESF and development assistance availa...  hr5368-102.16
# 96  Expresses the sense of the Congress that the r...  hr5368-102.17
# 97                 Prohibits ESF assistance to Zaire.  hr5368-102.18
# 98  Limits the amount of ESF assistance for tied a...  hr5368-102.19
# 99  Withholds a specified amount of funds allocate...  hr5368-102.20
#
#                                                 lower  \
# 0   provides for the enforcement of all provisions...
# 1   requires the delivery of excess defense articl...
# 2   prohibits making available any esf or foreign ...
# 3   prohibits the obligation of funds for the euro...
# 4   prohibits assistance to countries which fail t...
# ..                                                ...
# 95  earmarks esf and development assistance availa...
# 96  expresses the sense of the congress that the r...
# 97                 prohibits esf assistance to zaire.
# 98  limits the amount of esf assistance for tied a...
# 99  withholds a specified amount of funds allocate...
#
#                                                clean2  \
# 0   provides for the enforcement of all provisions...
# 1   requires the delivery of excess defense articl...
# 2   prohibits making available any esf or foreign ...
# 3   prohibits the obligation of funds for the euro...
# 4   prohibits assistance to countries which fail t...
# ..                                                ...
# 95  earmarks esf and development assistance availa...
# 96  expresses the sense of the congress that the r...
# 97                  prohibits esf assistance to zaire
# 98  limits the amount of esf assistance for tied a...
# 99  withholds a specified amount of funds allocate...
#
#                                                clean3  \
# 0   [provides, enforcement, provisions, law, impos...
# 1   [requires, delivery, excess, defense, articles...
# 2   [prohibits, making, available, esf, foreign, m...
# 3   [prohibits, obligation, funds, european, bank,...
# 4   [prohibits, assistance, countries, fail, take,...
# ..                                                ...
# 95  [earmarks, esf, development, assistance, avail...
# 96  [expresses, sense, congress, recommended, leve...
# 97                [prohibits, esf, assistance, zaire]
# 98  [limits, amount, esf, assistance, tied, aid, c...
# 99  [withholds, specified, amount, funds, allocate...
#
#                                                clean4  \
# 0   [provides, enforcement, provisions, law, impos...
# 1   [requires, delivery, excess, defense, articles...
# 2   [prohibits, making, available, esf, foreign, m...
# 3   [prohibits, obligation, funds, european, bank,...
# 4   [prohibits, assistance, countries, fail, take,...
# ..                                                ...
# 95  [earmarks, esf, development, assistance, avail...
# 96  [expresses, sense, congress, recommended, leve...
# 97                [prohibits, esf, assistance, zaire]
# 98  [limits, amount, esf, assistance, tied, aid, c...
# 99  [withholds, specified, amount, funds, allocate...
#
#                                                clean5  \
# 0   [provid, enforc, provis, law, impos, sanction,...
# 1   [requir, deliveri, excess, defens, articl, nat...
# 2   [prohibit, make, avail, esf, foreign, militari...
# 3   [prohibit, oblig, fund, european, bank, recons...
# 4   [prohibit, assist, countri, fail, take, step, ...
# ..                                                ...
# 95  [earmark, esf, develop, assist, avail, humanit...
# 96  [express, sens, congress, recommend, level, es...
# 97                      [prohibit, esf, assist, zair]
# 98  [limit, amount, esf, assist, tie, aid, credit,...
# 99  [withhold, specifi, amount, fund, alloc, domin...
#
#                                                clean6
# 0   provides enforcement provision law impose sanc...
# 1   requires delivery excess defense article nato ...
# 2   prohibits making available esf foreign militar...
# 3   prohibits obligation fund european bank recons...
# 4   prohibits assistance country fail take step pr...
# ..                                                ...
# 95  earmark esf development assistance available h...
# 96  express sense congress recommended level esf a...
# 97                     prohibits esf assistance zaire
# 98   limit amount esf assistance tied aid credit peru
# 99  withholds specified amount fund allocated domi...
#
# [100 rows x 8 columns]

# %%
w=Counter(" ".join(sascat["clean6"]).split()).most_common(10)
w=dict(w)
w
# Out:
# {'act': 70,
#  'assistance': 130,
#  'country': 75,
#  'fund': 67,
#  'government': 79,
#  'president': 89,
#  'prohibits': 62,
#  'sec': 53,
#  'state': 73,
#  'united': 53}

# %%
# plot
plt.bar(w.keys(), w.values())
plt.gcf().set_size_inches(20, 10)
plt.xticks(rotation=90)
plt.show()

# %%
#sascat.to_csv("sascat.csv")

# %% [markdown]
# **Excercise 2**
#
# Use this data you have just created.
#
#
# a) take a random sample of 1 row save them in a new dataframe called random
#
# b) keep only the rows that mention "human right" in the column where you only lower cased in our original dataset,
#
# c) take a random sample of 1 of those save the datafrae with the name "hr"
#
# e) create 6 lists from each of the columns [the 6 ways you have cleaned your data], print the content of all lists, do that for the dataframe random
#
# f) create 6 lists from each of the columns [the 6 ways you have cleaned your data], print the content of all lists, do that for the dataframe hr
#
# e) check overlap and difference between column 5 and column 6 (stemming and lemmatization pipelines) in the hr lists and in the random lists
#
# g) you see if you are writing a paper that needs to identify main topics for human rights, which of these processing mechanisms would you use and why?
#
# e) merge the rows of random and the row of hr - in a new dataframe called sanctions_random

# %%
random = sascat.sample(n=1) 
random.head()
# Out:
#                                               content             id  \
# 47  (Sec. 573) Directs the Secretary of the Treasu...  hjres2-108.36
#
#                                                 lower  \
# 47  (sec. 573) directs the secretary of the treasu...
#
#                                                clean2  \
# 47  sec  directs the secretary of the treasury to ...
#
#                                                clean3  \
# 47  [sec, directs, secretary, treasury, withhold, ...
#
#                                                clean4  \
# 47  [sec, directs, secretary, treasury, withhold, ...
#
#                                                clean5  \
# 47  [sec, direct, secretari, treasuri, withhold, t...
#
#                                                clean6
# 47  sec directs secretary treasury withhold ten pe...

# %%
one= (random['lower'].iloc[0]) #first row

# %%
one
# Out:
# '(sec. 573) directs the secretary of the treasury to withhold ten percent of the u.s. payment to any international financial institution until the secretary certifies that such institution has implemented certain procurement and financial management reforms.'

# %%
one= (random['lower'].iloc[-1])# first row
one=one.split()

# %%
one
# Out:
# ['(sec.',
#  '573)',
#  'directs',
#  'the',
#  'secretary',
#  'of',
#  'the',
#  'treasury',
#  'to',
#  'withhold',
#  'ten',
#  'percent',
#  'of',
#  'the',
#  'u.s.',
#  'payment',
#  'to',
#  'any',
#  'international',
#  'financial',
#  'institution',
#  'until',
#  'the',
#  'secretary',
#  'certifies',
#  'that',
#  'such',
#  'institution',
#  'has',
#  'implemented',
#  'certain',
#  'procurement',
#  'and',
#  'financial',
#  'management',
#  'reforms.']

# %%
one= (random['lower'].iloc[-1])# first row
one=one.split()
two=(random['clean2'].iloc[-1])
two=two.split()
three=(random['clean3'].iloc[-1])
four=(random['clean4'].iloc[-1])
five=(random['clean5'].iloc[-1])
six=(random['clean6'].iloc[-1])
six=six.split()


print(one)
print(two)
print(three)
print(four)
print(five)
print(six)
# Out:
# ['(sec.', '573)', 'directs', 'the', 'secretary', 'of', 'the', 'treasury', 'to', 'withhold', 'ten', 'percent', 'of', 'the', 'u.s.', 'payment', 'to', 'any', 'international', 'financial', 'institution', 'until', 'the', 'secretary', 'certifies', 'that', 'such', 'institution', 'has', 'implemented', 'certain', 'procurement', 'and', 'financial', 'management', 'reforms.']
# ['sec', 'directs', 'the', 'secretary', 'of', 'the', 'treasury', 'to', 'withhold', 'ten', 'percent', 'of', 'the', 'us', 'payment', 'to', 'any', 'international', 'financial', 'institution', 'until', 'the', 'secretary', 'certifies', 'that', 'such', 'institution', 'has', 'implemented', 'certain', 'procurement', 'and', 'financial', 'management', 'reforms']
# ['sec', 'directs', 'secretary', 'treasury', 'withhold', 'ten', 'percent', 'us', 'payment', 'international', 'financial', 'institution', 'secretary', 'certifies', 'institution', 'implemented', 'certain', 'procurement', 'financial', 'management', 'reforms']
# ['sec', 'directs', 'secretary', 'treasury', 'withhold', 'ten', 'percent', 'payment', 'international', 'financial', 'institution', 'secretary', 'certifies', 'institution', 'implemented', 'certain', 'procurement', 'financial', 'management', 'reforms']
# ['sec', 'direct', 'secretari', 'treasuri', 'withhold', 'ten', 'percent', 'payment', 'intern', 'financi', 'institut', 'secretari', 'certifi', 'institut', 'implement', 'certain', 'procur', 'financi', 'manag', 'reform']
# ['sec', 'directs', 'secretary', 'treasury', 'withhold', 'ten', 'percent', 'payment', 'international', 'financial', 'institution', 'secretary', 'certifies', 'institution', 'implemented', 'certain', 'procurement', 'financial', 'management', 'reform']

# %%
#check overlap between lemmatization and stemming
print("overlap:",list(set(five) & set(six)))
print("difference:",(set(five) - set(six)))
# Out:
# overlap: ['ten', 'payment', 'withhold', 'sec', 'certain', 'reform', 'percent']
# difference: {'secretari', 'financi', 'treasuri', 'manag', 'implement', 'institut', 'certifi', 'intern', 'direct', 'procur'}

# %%
hr= sascat[sascat['lower'].str.contains("human right")]
hr1=hr.sample(n=1)
hr1.head()
# Out:
#                                               content            id  \
# 11  Authorizes the President to deny U.S. entry to...  hr5948-109.1
#
#                                                 lower  \
# 11  authorizes the president to deny u.s. entry to...
#
#                                                clean2  \
# 11  authorizes the president to deny us entry to a...
#
#                                                clean3  \
# 11  [authorizes, president, deny, us, entry, alien...
#
#                                                clean4  \
# 11  [authorizes, president, deny, entry, alien, se...
#
#                                                clean5  \
# 11  [author, presid, deni, entri, alien, senior, l...
#
#                                                clean6
# 11  authorizes president deny entry alien senior l...

# %%
one_hr= (hr1['lower'].iloc[-1])
one_hr=one_hr.split()
two_hr=(hr1['clean2'].iloc[-1])
two_hr=two_hr.split()
three_hr=(hr1['clean3'].iloc[-1])
four_hr=(hr1['clean4'].iloc[-1])
five_hr=(hr1['clean5'].iloc[-1])
six_hr=(hr1['clean6'].iloc[-1])
six_hr=six_hr.split()


print(one_hr)
print(two_hr)
print(three_hr)
print(four_hr)
print(five_hr)
print(six_hr)
# Out:
# ['authorizes', 'the', 'president', 'to', 'deny', 'u.s.', 'entry', 'to', 'any', 'alien', 'who:', '(1)', 'is', 'in', 'the', 'senior', 'leadership', 'of', 'the', 'government', 'of', 'belarus;', '(2)', 'is', 'an', 'immediate', 'family', 'member', 'of', 'such', 'person;', 'or', '(3)', 'through', 'business', 'dealings', 'with', 'senior', 'government', 'leadership', 'derives', 'significant', 'financial', 'benefit', 'from', 'policies', 'or', 'actions', 'that', 'undermine', 'democratic', 'institutions', 'or', 'impede', "belarus'", 'transition', 'to', 'democracy.', 'expresses', 'the', 'sense', 'of', 'congress', 'that:', '(1)', 'no', 'loan,', 'credit', 'guarantee,', 'insurance,', 'financing,', 'or', 'other', 'similar', 'financial', 'assistance', 'should', 'be', 'extended', 'by', 'any', 'u.s.', 'agency', '(including', 'the', 'export-import', 'bank', 'and', 'the', 'overseas', 'private', 'investment', 'corporation)', 'to', 'the', 'government', 'of', 'belarus,', 'except', 'for', 'humanitarian', 'goods', 'and', 'agricultural', 'or', 'medical', 'products;', 'and', '(2)', 'no', 'funds', 'available', 'to', 'the', 'trade', 'and', 'development', 'agency', 'should', 'be', 'available', 'for', 'agency', 'activities', 'in', 'or', 'for', 'belarus.', 'expresses', 'the', 'sense', 'of', 'congress', 'that', 'the', 'president', 'should', 'block', 'all', 'property', 'and', 'property', 'interests', 'that', 'on', 'or', 'after', 'the', 'date', 'of', 'the', 'enactment', 'of', 'this', 'act:', '(1)', 'are', 'owned', 'in', 'whole', 'or', 'in', 'part', 'by', 'the', 'government', 'of', 'belarus,', 'or', 'by', 'any', 'member', 'or', 'family', 'member', 'closely', 'linked', 'to', 'senior', 'government', 'leadership,', 'or', 'any', 'person', 'who', 'through', 'business', 'dealings', 'with', 'senior', 'government', 'leadership', 'derives', 'significant', 'financial', 'benefit', 'from', 'policies', 'or', 'actions', 'that', 'undermine', 'or', 'injure', 'democratic', 'institutions', 'or', 'impede', "belarus'", 'transition', 'to', 'democracy;', 'and', '(2)', 'are', 'in', 'the', 'united', 'states,', 'or', 'in', 'the', 'possession', 'or', 'control', 'of', 'the', 'u.s.', 'government', 'or', 'of', 'any', 'u.s.', 'financial', 'institution,', 'including', 'any', 'branch', 'or', 'office', 'located', 'outside', 'the', 'united', 'states.', 'states', 'that', 'activities', 'prohibited', 'by', 'the', 'blocking', 'of', 'such', 'property', 'interests', 'should', 'include:', '(1)', 'payments', 'or', 'transfers', 'of', 'property', 'or', 'anything', 'of', 'economic', 'value', 'by', 'any', 'u.s.', 'person', 'to', 'the', 'government', 'of', 'belarus', 'or', 'to', 'any', 'entity', 'or', 'person', 'acting', 'on', 'its', 'behalf,', 'or', 'to', 'any', 'member', 'of', 'its', 'senior', 'leadership;', '(2)', 'the', 'export', 'or', 'reexport', 'to', 'any', 'entity', 'owned,', 'controlled,', 'or', 'operated', 'by', 'the', 'government', 'of', 'belarus', 'of', 'any', 'goods,', 'technology,', 'or', 'services,', 'either', 'by', 'a', 'u.s.', 'person', 'or', 'involving', 'the', 'use', 'of', 'any', 'air', 'carrier', 'or', 'a', 'vessel', 'documented', 'under', 'u.s.', 'law;', 'and', '(3)', 'the', 'performance', 'by', 'any', 'u.s.', 'person', 'of', 'any', 'contract,', 'including', 'a', 'contract', 'providing', 'a', 'loan', 'or', 'other', 'financing,', 'in', 'support', 'of', 'an', 'industrial,', 'commercial,', 'or', 'public', 'utility', 'operated,', 'controlled,', 'or', 'owned', 'by', 'the', 'government', 'of', 'belarus.', 'exempts', 'from', 'such', 'prohibitions:', '(1)', 'assistance', 'under', 'sections', '4', 'or', '5', 'of', 'this', 'act;', 'or', '(2)', 'medicine,', 'medical', 'equipment,', 'food,', 'or', 'other', 'humanitarian', 'assistance', 'provided', 'to', 'belarus', 'in', 'response', 'to', 'a', 'humanitarian', 'crisis.', 'belarus', 'democracy', 'reauthorization', 'act', 'of', '2006', '-', '(sec.', '3)', 'amends', 'the', 'belarus', 'democracy', 'act', 'of', '2004', 'to', 'state', 'that', 'it', 'is', 'u. ...
# ['authorizes', 'the', 'president', 'to', 'deny', 'us', 'entry', 'to', 'any', 'alien', 'who', 'is', 'in', 'the', 'senior', 'leadership', 'of', 'the', 'government', 'of', 'belarus', 'is', 'an', 'immediate', 'family', 'member', 'of', 'such', 'person', 'or', 'through', 'business', 'dealings', 'with', 'senior', 'government', 'leadership', 'derives', 'significant', 'financial', 'benefit', 'from', 'policies', 'or', 'actions', 'that', 'undermine', 'democratic', 'institutions', 'or', 'impede', 'belarus', 'transition', 'to', 'democracy', 'expresses', 'the', 'sense', 'of', 'congress', 'that', 'no', 'loan', 'credit', 'guarantee', 'insurance', 'financing', 'or', 'other', 'similar', 'financial', 'assistance', 'should', 'be', 'extended', 'by', 'any', 'us', 'agency', 'including', 'the', 'exportimport', 'bank', 'and', 'the', 'overseas', 'private', 'investment', 'corporation', 'to', 'the', 'government', 'of', 'belarus', 'except', 'for', 'humanitarian', 'goods', 'and', 'agricultural', 'or', 'medical', 'products', 'and', 'no', 'funds', 'available', 'to', 'the', 'trade', 'and', 'development', 'agency', 'should', 'be', 'available', 'for', 'agency', 'activities', 'in', 'or', 'for', 'belarus', 'expresses', 'the', 'sense', 'of', 'congress', 'that', 'the', 'president', 'should', 'block', 'all', 'property', 'and', 'property', 'interests', 'that', 'on', 'or', 'after', 'the', 'date', 'of', 'the', 'enactment', 'of', 'this', 'act', 'are', 'owned', 'in', 'whole', 'or', 'in', 'part', 'by', 'the', 'government', 'of', 'belarus', 'or', 'by', 'any', 'member', 'or', 'family', 'member', 'closely', 'linked', 'to', 'senior', 'government', 'leadership', 'or', 'any', 'person', 'who', 'through', 'business', 'dealings', 'with', 'senior', 'government', 'leadership', 'derives', 'significant', 'financial', 'benefit', 'from', 'policies', 'or', 'actions', 'that', 'undermine', 'or', 'injure', 'democratic', 'institutions', 'or', 'impede', 'belarus', 'transition', 'to', 'democracy', 'and', 'are', 'in', 'the', 'united', 'states', 'or', 'in', 'the', 'possession', 'or', 'control', 'of', 'the', 'us', 'government', 'or', 'of', 'any', 'us', 'financial', 'institution', 'including', 'any', 'branch', 'or', 'office', 'located', 'outside', 'the', 'united', 'states', 'states', 'that', 'activities', 'prohibited', 'by', 'the', 'blocking', 'of', 'such', 'property', 'interests', 'should', 'include', 'payments', 'or', 'transfers', 'of', 'property', 'or', 'anything', 'of', 'economic', 'value', 'by', 'any', 'us', 'person', 'to', 'the', 'government', 'of', 'belarus', 'or', 'to', 'any', 'entity', 'or', 'person', 'acting', 'on', 'its', 'behalf', 'or', 'to', 'any', 'member', 'of', 'its', 'senior', 'leadership', 'the', 'export', 'or', 'reexport', 'to', 'any', 'entity', 'owned', 'controlled', 'or', 'operated', 'by', 'the', 'government', 'of', 'belarus', 'of', 'any', 'goods', 'technology', 'or', 'services', 'either', 'by', 'a', 'us', 'person', 'or', 'involving', 'the', 'use', 'of', 'any', 'air', 'carrier', 'or', 'a', 'vessel', 'documented', 'under', 'us', 'law', 'and', 'the', 'performance', 'by', 'any', 'us', 'person', 'of', 'any', 'contract',
'injure', 'democratic', 'institution', 'impede', 'belarus', 'transition', 'democracy', 'united', 'state', 'possession', 'control', 'government', 'financial', 'institution', 'including', 'branch', 'office', 'located', 'outside', 'united', 'state', 'state', 'activity', 'prohibited', 'blocking', 'property', 'interest', 'include', 'payment', 'transfer', 'property', 'anything', 'economic', 'value', 'person', 'government', 'belarus', 'entity', 'person', 'acting', 'behalf', 'member', 'senior', 'leadership', 'export', 'reexport', 'entity', 'owned', 'controlled', 'operated', 'government', 'belarus', 'good', 'technology', 'service', 'either', 'person', 'involving', 'use', 'air', 'carrier', 'vessel', 'documented', 'law', 'performance', 'person', 'contract', 'including', 'contract', 'providing', 'loan', 'financing', 'support', 'industrial', 'commercial', 'public', 'utility', 'operated', 'controlled', 'owned', 'government', 'belarus', 'exempts', 'prohibition', 'assistance', 'section', 'act', 'medicine', 'medical', 'equipment', 'food', 'humanitarian', 'assistance', 'provided', 'belarus', 'response', 'humanitarian', 'crisis', 'belarus', 'democracy', 'reauthorization', 'act', 'sec', 'amends', 'belarus', 'democracy', 'act', 'state', 'policy', 'call', 'immediate', 'release', 'political', 'prisoner', 'belarus', 'support', 'aspiration', 'people', 'republic', 'belarus', 'democracy', 'human', 'right', 'rule', 'law', 'preserve', 'country', 'independence', 'support', 'growth', 'democratic', 'movement', 'institution', 'belarus', 'refuse', 'accept', 'result', 'march', 'presidential', 'election', 'belarus', 'support', 'new', 'presidential', 'election', 'refuse', 'recognize', 'referendum', 'would', 'affect', 'belarus', 'sovereignty', 'work', 'country', 'international', 'organization', 'promote', 'belarus', 'integration', 'european', 'community', 'democracy', 'sec', 'revise', 'activity', 'may', 'supported', 'assistance', 'act', 'including', 'support', 'youth', 'group', 'independent', 'trade', 'union', 'entrepreneur', 'human', 'right', 'defender', 'independent', 'medium', 'democratic', 'political', 'party', 'international', 'exchange', 'extends', 'authorization', 'appropriation', 'sec', 'includes', 'television', 'broadcasting', 'within', 'scope', 'increased', 'support', 'funding', 'government', 'surrogate', 'broadcasting', 'belarus', 'currently', 'support', 'limited', 'radio', 'broadcasting', 'sec', 'establishes', 'specified', 'economic', 'entry', 'sanction', 'belarus', 'president', 'certifies', 'appropriate', 'congressional', 'committee', 'government', 'belarus', 'made', 'progress', 'meeting', 'specified', 'condition', 'respecting', 'release', 'political', 'religious', 'prisoner', 'accounting', 'disappearance', 'opposition', 'leader', 'journalist', 'cessation', 'political', 'hara ...

# %%
#check overlap between lemmatization and stemming
print("overlap:",list(set(five_hr) & set(six_hr)))
print()
print("difference:",(set(five_hr) - set(six_hr)))
# Out:
# overlap: ['leadership', 'result', 'senior', 'person', 'behalf', 'entrepreneur', 'leader', 'belarus', 'similar', 'radio', 'contract', 'within', 'payment', 'air', 'carrier', 'export', 'support', 'block', 'food', 'affect', 'control', 'action', 'new', 'may', 'use', 'reexport', 'fund', 'growth', 'accept', 'branch', 'member', 'law', 'work', 'youth', 'asset', 'referendum', 'good', 'progress', 'part', 'call', 'vessel', 'section', 'scope', 'rule', 'union', 'act', 'credit', 'alien', 'sanction', 'congress', 'trade', 'benefit', 'human', 'product', 'sec', 'would', 'free', 'group', 'march', 'except', 'bank', 'made', 'interest', 'state', 'european', 'humanitarian', 'movement', 'loan', 'whole', 'date', 'right', 'express', 'either', 'public', 'journalist', 'transfer']
#
# difference: {'insur', 'revis', 'televis', 'polici', 'immedi', 'avail', 'prosecut', 'condit', 'guarante', 'busi', 'prohibit', 'medicin', 'injur', 'privat', 'deal', 'commerci', 'supervis', 'broadcast', 'develop', 'deni', 'religi', 'countri', 'outsid', 'valu', 'preserv', 'polit', 'opposit', 'democrat', 'peopl', 'embezzl', 'financ', 'servic', 'entiti', 'refus', 'sens', 'perform', 'increas', 'technolog', 'releas', 'integr', 'own', 'equip', 'presid', 'amend', 'oversea', 'econom', 'provid', 'undermin', 'medic', 'industri', 'democraci', 'recogn', 'harass', 'aspir', 'anyth', 'transit', 'invest', 'properti', 'agricultur', 'exempt', 'respect', 'involv', 'deriv', 'locat', 'link', 'certifi', 'surrog', 'presidenti', 'fraudul', 'signific', 'imped', 'limit', 'crisi', 'assist', 'committe', 'disappear', 'elect', 'possess', 'govern', 'promot', 'meet', 'reauthor', 'institut', 'agenc', 'unit', 'extend', 'media', 'offic', 'author', 'specifi', 'enact', 'establish', 'cessat', 'famili', 'appropri', 'administr', 'republ', 'close', 'document', 'account', 'parliamentari', 'includ', 'util', 'financi', 'activ', 'prison', 'respons', 'entri', 'independ', 'communiti', 'oper', 'intern', 'organ', 'congression', 'corpor', 'exchang', 'sovereignti', 'hold', 'current', 'defend', 'parti'}

# %%
sanctions_random=pd.concat([random, hr1])
sanctions_random
# Out:
#                                               content             id  \
# 47  (Sec. 573) Directs the Secretary of the Treasu...  hjres2-108.36
# 11  Authorizes the President to deny U.S. entry to...   hr5948-109.1
#
#                                                 lower  \
# 47  (sec. 573) directs the secretary of the treasu...
# 11  authorizes the president to deny u.s. entry to...
#
#                                                clean2  \
# 47  sec  directs the secretary of the treasury to ...
# 11  authorizes the president to deny us entry to a...
#
#                                                clean3  \
# 47  [sec, directs, secretary, treasury, withhold, ...
# 11  [authorizes, president, deny, us, entry, alien...
#
#                                                clean4  \
# 47  [sec, directs, secretary, treasury, withhold, ...
# 11  [authorizes, president, deny, entry, alien, se...
#
#                                                clean5  \
# 47  [sec, direct, secretari, treasuri, withhold, t...
# 11  [author, presid, deni, entri, alien, senior, l...
#
#                                                clean6
# 47  sec directs secretary treasury withhold ten pe...
# 11  authorizes president deny entry alien senior l...

# %%
#sources

#Denny, M., & Spirling, A. (2018). Text Preprocessing For Unsupervised Learning: Why It Matters, When It Misleads, And What To Do About It. Political Analysis, 26(2), 168-189. doi:10.1017/pan.2017.44
#https://towardsdatascience.com/stemming-lemmatization-what-ba782b7c0bd8
#https://github.com/makcedward/nlp/blob/master/sample/nlp-stemming.ipynb
#https://github.com/makcedward/nlp/blob/master/sample/nlp_lemmatization.ipynb
#https://www.datacamp.com/community/tutorials/stemming-lemmatization-python
#https://opendatagroup.github.io/data%20science/2019/03/21/preprocessing-text.html
